# %% [markdown]
# # Homework 1
# This file contains a few lines of code that I needed to generate plots for Homework 1 for MATH 5440. This course is focused on PDEs and was taught by Braxton Osting at The University of Utah during the Fall 2026 semester.

# %% [markdown]
# Import packages

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# Homework Problem 4(a): Define the solution to Problem 3, calculated by hand using d'Alembert's formula.

# %%
def u(x,t):
    sol = 0.5*np.log((1+(x+t)**2)*(1+(x-t)**2))+4*t+x*t
    return sol
